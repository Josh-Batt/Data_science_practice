# %% [markdown]
# # Imports

# %%
import time

import numpy    as np
import pandas   as pd
import seaborn  as sns
import matplotlib.pyplot as plt
import sklearn  as skl

from sklearn import pipeline      # Pipeline
from sklearn import preprocessing # OrdinalEncoder, LabelEncoder
from sklearn import impute
from sklearn import compose
from sklearn import model_selection # train_test_split
from sklearn import metrics         # accuracy_score, balanced_accuracy_score, plot_confusion_matrix
from sklearn import linear_model    # LogisticRegression
from sklearn import set_config

set_config(display='diagram') # Useful for display the pipeline

print("Pandas  ", pd.__version__)
print("Sklearn ", skl.__version__)
# Out:
# Pandas   1.3.0
# Sklearn  0.24.2

# %% [markdown]
# # Load data

# %%
df_test = pd.read_csv("test.csv", index_col='PassengerId')
df_train = pd.read_csv("train.csv", index_col = 'PassengerId')

# %% [markdown]
# # Check data

# %% [markdown]
# PassangerID - Leave alone
#
# HomePlanet - Turn Earch Europa and Mars into numerical data -> Use onehotencoding
#
# CryoSleep - Turn to 0 and 1
#
# Cabin - Split into 3 columns. Deck, Number, Side
#
#     Deck - onehotencode
#     cabin - leave
#     side - onehotencode
#
# Destination - Turn the 3 destinations into numbers -> Use onehotencoding
#
# Age - Turn into int
#
# VIP - Turn into 0 and 1
#
# RoomService, FoodCourt, ShoppingMall, Spa, VRDeck - Turn into ints.
#
# Name - Turn into 2 coloumns. First name and Last name
#
# Create a new coloumn based on family, use last name data to create this boolean coloumn

# %%
df_test
# Out:
#             HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# PassengerId
# 0013_01          Earth      True     G/3/S    TRAPPIST-1e  27.0  False
# 0018_01          Earth     False     F/4/S    TRAPPIST-1e  19.0  False
# 0019_01         Europa      True     C/0/S    55 Cancri e  31.0  False
# 0021_01         Europa     False     C/1/S    TRAPPIST-1e  38.0  False
# 0023_01          Earth     False     F/5/S    TRAPPIST-1e  20.0  False
# ...                ...       ...       ...            ...   ...    ...
# 9266_02          Earth      True  G/1496/S    TRAPPIST-1e  34.0  False
# 9269_01          Earth     False       NaN    TRAPPIST-1e  42.0  False
# 9271_01           Mars      True   D/296/P    55 Cancri e   NaN  False
# 9273_01         Europa     False   D/297/P            NaN   NaN  False
# 9277_01          Earth      True  G/1498/S  PSO J318.5-22  43.0  False
#
#              RoomService  FoodCourt  ShoppingMall     Spa  VRDeck  \
# PassengerId
# ...

# %%
df_train
# Out:
#             HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# PassengerId
# 0001_01         Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 0002_01          Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 0003_01         Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 0003_02         Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 0004_01          Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...                ...       ...       ...            ...   ...    ...
# 9276_01         Europa     False    A/98/P    55 Cancri e  41.0   True
# 9278_01          Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 9279_01          Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 9280_01         Europa     False   E/608/S    55 Cancri e  32.0  False
# 9280_02         Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
#              RoomService  FoodCourt  ShoppingMall     Spa  VRDeck  \
# PassengerId
# ...

# %%
df_train.isnull().sum()/len(df_train)
# Out:
# HomePlanet      0.023122
# CryoSleep       0.024963
# Cabin           0.022892
# Destination     0.020936
# Age             0.020591
# VIP             0.023352
# RoomService     0.020821
# FoodCourt       0.021051
# ShoppingMall    0.023927
# Spa             0.021051
# VRDeck          0.021627
# Name            0.023007
# Transported     0.000000
# dtype: float64

# %%
df_test.isnull().sum()/len(df_test)
# Out:
# HomePlanet      0.020341
# CryoSleep       0.021744
# Cabin           0.023381
# Destination     0.021510
# Age             0.021277
# VIP             0.021744
# RoomService     0.019172
# FoodCourt       0.024784
# ShoppingMall    0.022913
# Spa             0.023615
# VRDeck          0.018705
# Name            0.021978
# dtype: float64

# %%
df_train.HomePlanet.value_counts()
# Out:
# Earth     4602
# Europa    2131
# Mars      1759
# Name: HomePlanet, dtype: int64

# %%
df_train.Destination.value_counts()
# Out:
# TRAPPIST-1e      5915
# 55 Cancri e      1800
# PSO J318.5-22     796
# Name: Destination, dtype: int64

# %% [markdown]
# # Data prep for plots

# %%
# HomePlanet_to_nums = {"Earth" : 0, "Europa" : 1, "Mars" : 2}
# CryoSleep_to_nums = {True : 1, False : 0}
# Cabin_to

# %%
df_train['Name'].count()
# Out:
# 8493

# %%
small_df = df_train['Name'].str.extract(r'(?P<First_Name>\w+) (?P<Last_Name>\w+)', expand=True)
small_df.count()
# Out:
# First_Name    8493
# Last_Name     8493
# dtype: int64

# %%
plotting_df_train = pd.concat([df_train, small_df], axis=1)
plotting_df_train
# Out:
#             HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# PassengerId
# 0001_01         Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 0002_01          Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 0003_01         Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 0003_02         Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 0004_01          Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...                ...       ...       ...            ...   ...    ...
# 9276_01         Europa     False    A/98/P    55 Cancri e  41.0   True
# 9278_01          Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 9279_01          Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 9280_01         Europa     False   E/608/S    55 Cancri e  32.0  False
# 9280_02         Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
#              RoomService  FoodCourt  ShoppingMall     Spa  VRDeck  \
# PassengerId
# ...

# %%
plotting_df_train = plotting_df_train.drop(columns=['Name'])

# %%
plotting_df_train
# Out:
#             HomePlanet CryoSleep     Cabin    Destination   Age    VIP  \
# PassengerId
# 0001_01         Europa     False     B/0/P    TRAPPIST-1e  39.0  False
# 0002_01          Earth     False     F/0/S    TRAPPIST-1e  24.0  False
# 0003_01         Europa     False     A/0/S    TRAPPIST-1e  58.0   True
# 0003_02         Europa     False     A/0/S    TRAPPIST-1e  33.0  False
# 0004_01          Earth     False     F/1/S    TRAPPIST-1e  16.0  False
# ...                ...       ...       ...            ...   ...    ...
# 9276_01         Europa     False    A/98/P    55 Cancri e  41.0   True
# 9278_01          Earth      True  G/1499/S  PSO J318.5-22  18.0  False
# 9279_01          Earth     False  G/1500/S    TRAPPIST-1e  26.0  False
# 9280_01         Europa     False   E/608/S    55 Cancri e  32.0  False
# 9280_02         Europa     False   E/608/S    TRAPPIST-1e  44.0  False
#
#              RoomService  FoodCourt  ShoppingMall     Spa  VRDeck  \
# PassengerId
# ...

# %%
deck_df = df_train['Cabin'].str.strip('/').str[0]
deck_df
# Out:
# PassengerId
# 0001_01    B
# 0002_01    F
# 0003_01    A
# 0003_02    A
# 0004_01    F
#           ..
# 9276_01    A
# 9278_01    G
# 9279_01    G
# 9280_01    E
# 9280_02    E
# Name: Cabin, Length: 8693, dtype: object

# %%
num_df = df_train['Cabin'].str.split("/", 2)
num_df[1][1].astype
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21748/3099984343.py in <module>
#       1 num_df = df_train['Cabin'].str.split("/", 2)
# ----> 2 num_df[1][1].astype
#
# AttributeError: 'str' object has no attribute 'astype'

# %%
[sublist[:1] for sublist in num_df]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21748/1986139095.py in <module>
# ----> 1 [sublist[:1] for sublist in num_df]
#
# ~\AppData\Local\Temp/ipykernel_21748/1986139095.py in <listcomp>(.0)
# ----> 1 [sublist[:1] for sublist in num_df]
#
# TypeError: 'float' object is not subscriptable

# %%
side_df = df_train['Cabin'].str.strip('/').str[-1]
side_df[-1]
# Out:
# 'S'

# %% [markdown]
# # Ignore for now

# %%
cat_vars = ['HomePlanet', 'CryoSleep', ]
num_vars = ['Pclass', 'Sex', 'Age', 'SibSp', 'Parch']

# %%
num_prepoccessing = pipeline.Pipeline(steps=[
    ('impute', impute.SimpleImputer(strategy='mean', add_indicator=False)),
    ('scaler', preprocessing.StandardScaler())
])
str_prepoccessing = pipeline.Pipeline(steps=[
    ('impute', impute.SimpleImputer(strategy='constant', add_indicator=False)),
    ('onehot', preprocessing.OneHotEncoder(handle_unknown='ignore'))
])
prepro = compose.ColumnTransformer(transformers=[
    ('num', num_prepoccessing, num_vars),
    ('str', str_prepoccessing, str_vars)
])

prepro
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_21748/876681547.py in <module>
#       9 prepro = compose.ColumnTransformer(transformers=[
#      10     ('num', num_prepoccessing, num_vars),
# ---> 11     ('str', str_prepoccessing, str_vars)
#      12 ])
#      13
#
# NameError: name 'str_vars' is not defined

# %% [markdown]
# # Plots

# %%
df_train.corr()
